# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets



# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Ztrni2ePZEBOO7ZJZMUk")
project = rf.workspace("varun-yvyoy").project("invoice-processing-nl2cz")
dataset = project.version(1).download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.123, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to Invoice-Processing-1 in yolov8:: 100%|██████████| 512/512 [00:00<00:00, 1784.30it/s]

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/content/best.pt conf=0.25 source={dataset.location}/test/images save=True

model=YOLO('/content/best.pt')
results= model.predict('/content/datasets/Invoice-Processing-1/test/images/128_png_jpg.rf.8de9fb837e3f3a675e6b161ad64602cf.jpg')

# %%
# from ultralytics import YOLO
import cv2

# model = YOLO('yolov8n.pt')
# results = model('https://ultralytics.com/images/bus.jpg')
img = cv2.imread('/content/datasets/Invoice-Processing-1/test/images/128_png_jpg.rf.8de9fb837e3f3a675e6b161ad64602cf.jpg')


for result in results:
    boxes = result.boxes.cpu().numpy()
for result in results:

    boxes = result.boxes.cpu().numpy()
    for i, box in enumerate(boxes):
        name=result.names[int(box.cls)]
        r = box.xyxy[0].astype(int)
        crop = img[r[1]:r[3], r[0]:r[2]]
        cv2.imwrite(str(name) + ".jpg", crop)
